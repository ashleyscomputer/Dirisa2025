# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use("seaborn-v0_8")

df = pd.read_csv("Parquet_file.csv")

df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[14], line 8
#       4 import seaborn as sns
#       6 plt.style.use("seaborn-v0_8")
# ----> 8 df = pd.read_csv("Parquet_file.csv")
#      10 df.head()
#
# ...

# %%
# Step 1: Load and preview the dataset
import pandas as pd

# Load the CSV file
df = pd.read_csv("Parquet_file.csv")  # replace with your file path

# 1️⃣ Quick peek at the first 5 rows
print("First 5 rows of the dataset:")
display(df.head())

# 2️⃣ Basic info: column types and missing values
print("\nDataset info:")
df.info()

# 3️⃣ Quick stats for numeric columns
print("\nSummary statistics for numeric columns:")
display(df.describe())

# 4️⃣ Optional: check dataset shape
print("\nDataset shape (rows, columns):", df.shape)
# Out:
# First 5 rows of the dataset:
#    Unnamed: 0       sourceimei  battery_voltage_value  \
# 0           0  869716067485269              12.484994
# 1           1  869716067485269              12.845138
# 2           2  869716067485269              12.845138
# 3           3  869716067485269              12.845138
# 4           4  869716067485269              12.845138
#
#    hardware_attached_gps_not_present            unitdatetime eventid  \
# 0                                  1  2025-10-08 11:24:34 PM      5E
# 1                                  1  2025-10-08 03:59:49 PM      02
# 2                                  1  2025-10-08 03:59:50 PM      02
# 3                                  1  2025-10-08 03:59:51 PM      02
# 4                                  1  2025-10-08 03:59:51 PM      00
#
#     latitude  longitude  altitude  speed  ...  distance_suburb  \
# 0 -26.122560  28.078880    1639.0      0  ...                0
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Select only numeric columns
numeric_cols = df.select_dtypes(include=['float64', 'int64']).columns

# Compute correlation matrix
corr_matrix = df[numeric_cols].corr()

# Plot heatmap
plt.figure(figsize=(14,10))
sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap='coolwarm', cbar=True)
plt.title("Correlation Heatmap of Numeric Variables")
plt.show()

# %%
# Step 1: Load and preview the dataset
import pandas as pd

# Load the CSV file
df = pd.read_csv("Parquet_file.csv")  # replace with your file path

# 1️⃣ Quick peek at the first 5 rows
print("First 5 rows of the dataset:")
display(df.head())

# 2️⃣ Basic info: column types and missing values
print("\nDataset info:")
df.info()

# 3️⃣ Quick stats for numeric columns
print("\nSummary statistics for numeric columns:")
display(df.describe())

# 4️⃣ Optional: check dataset shape
print("\nDataset shape (rows, columns):", df.shape)
# Out:
# First 5 rows of the dataset:
#    Unnamed: 0       sourceimei  battery_voltage_value  \
# 0           0  869716067485269              12.484994
# 1           1  869716067485269              12.845138
# 2           2  869716067485269              12.845138
# 3           3  869716067485269              12.845138
# 4           4  869716067485269              12.845138
#
#    hardware_attached_gps_not_present            unitdatetime eventid  \
# 0                                  1  2025-10-08 11:24:34 PM      5E
# 1                                  1  2025-10-08 03:59:49 PM      02
# 2                                  1  2025-10-08 03:59:50 PM      02
# 3                                  1  2025-10-08 03:59:51 PM      02
# 4                                  1  2025-10-08 03:59:51 PM      00
#
#     latitude  longitude  altitude  speed  ...  distance_suburb  \
# 0 -26.122560  28.078880    1639.0      0  ...                0
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10,8))
sns.scatterplot(
    x='longitude',
    y='latitude',
    hue='speed',            # color points by speed
    size='gforce_forward',  # size points by forward g-force
    sizes=(20, 200),
    data=df,
    palette='viridis',
    alpha=0.6
)
plt.title("Vehicle Locations Colored by Speed & Sized by Forward G-Force")
plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.legend(title='Speed / G-Force')
plt.show()

# %%
import geopandas as gpd
from shapely.geometry import Point

# Convert your telematics df into a GeoDataFrame
gdf_1 = gpd.GeoDataFrame(
    df,
    geometry=gpd.points_from_xy(df.longitude, df.latitude),
    crs="EPSG:4326"
)

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import numpy as np
import os

os.chdir(r"C:\Users\Ashley\Downloads\ZAF_adm (2)\ZAF_adm")
gdf = gpd.read_file('ZAF_adm2.shp')

# %%
gdf.head(10)
# Out:
#    ID_0  ISO        NAME_0  ID_1        NAME_1  ID_2        NAME_2  \
# 0   211  ZAF  South Africa     1  Eastern Cape     1      Aberdeen
# 1   211  ZAF  South Africa     1  Eastern Cape     2      Adelaide
# 2   211  ZAF  South Africa     1  Eastern Cape     3        Albany
# 3   211  ZAF  South Africa     1  Eastern Cape     4        Albert
# 4   211  ZAF  South Africa     1  Eastern Cape     5    Alexandria
# 5   211  ZAF  South Africa     1  Eastern Cape     6  Aliwal North
# 6   211  ZAF  South Africa     1  Eastern Cape     7   Barkly East
# 7   211  ZAF  South Africa     1  Eastern Cape     8      Bathurst
# 8   211  ZAF  South Africa     1  Eastern Cape     9       Bedford
# 9   211  ZAF  South Africa     1  Eastern Cape    10        Bizana
#
#                  TYPE_2             ENGTYPE_2 NL_NAME_2 VARNAME_2  \
# 0  Magisterial District  Magisterial District      None      None
# 1  Magisterial District  Magisterial District      None      None
# ...

# %%
fig, ax = plt.subplots(figsize = (10, 10))
prov = gdf[gdf['NAME_1'] == 'Gauteng']
prov.plot(
    ax = ax,
    facecolor = 'Grey', 
    edgecolor = 'k',
    alpha = 1,
    linewidth = 1,
    #cmap = "Greens"
)

sns.scatterplot(
    x='longitude',
    y='latitude',
    hue='speed',            # color points by speed
    size='gforce_forward',  # size points by forward g-force
    sizes=(100, 100),
    data=gdf_1,
    palette='viridis',
    alpha=0.6
)
# Out:
# <Axes: xlabel='longitude', ylabel='latitude'>
